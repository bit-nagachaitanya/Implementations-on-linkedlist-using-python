# %%
## Linked List using Python

class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class LinkedListLL:
    def __init__(self):
        self.head=None

    def InsertingNodeAtBegin(self,nd):
        New_node=Node(nd)
        if self.head is None:
            self.head=New_node
            print("Head Node added Successfully")
        else:
            #temp=self.head
            New_node.next=self.head
            self.head=New_node
            
            print("Node added at the Begin")

    def InsertingNodeAtEnd(self,nd):
        New_node=Node(nd)
        if self.head is None:
            self.head=New_node
            Print("Node added as head")
        temp=self.head
        while temp.next:
            temp=temp.next

        temp.next=New_node
        print("Node added at the end")

    def deleteNode(self,key):
        temp=self.head
        while temp :
            if temp.data == key:
                break
            else :
                prev=temp
                temp=temp.next
        temp=temp.next
        prev.next=temp
        temp=None
        print(f'key-> {key} is deleted')

    def deleteNodeFromPosition(self,position):
        temp=self.head
        c=0
        position=position-1
        while temp:
            #print(type(temp))
            c+=1
            temp=temp.next

        if position > c:
            print("Enter valid position")
            return 

        else:
            temp1=self.head
            for i in range(position):
                if temp1:
                    prev=temp1
                    temp1=temp1.next
            temp1=temp1.next
            prev.next=temp1
        

        print("Node deleted at the position ",position)

    def deleteNodeFromTheEndingIndex(self,FromLastPosition ):
        temp=self.head
        dummy=temp
        first=temp
        second=temp

        for i in range(1,FromLastPosition+2):
            temp=temp.next

        while temp:
            temp=temp.next
            second=second.next 

        second.next=second.next.next
        
        
        
    def PrintLL(self):
        if self.head is None:
            print("NO matter inside Linked List")
        else :
            temp=self.head
            while temp :
                print(temp.data,"=>",end=" ")
                temp=temp.next


ll1=LinkedListLL()
ll1.InsertingNodeAtBegin(1)
ll1.InsertingNodeAtBegin(3)
ll1.InsertingNodeAtBegin(4)
ll1.InsertingNodeAtEnd(5);
ll1.InsertingNodeAtEnd(6);
ll1.InsertingNodeAtEnd(7);
ll1.InsertingNodeAtEnd(8);
# ll1.PrintLL()
# ll1.deleteNodeFromPosition(4)
ll1.PrintLL()
print()
ll1.deleteNodeFromTheEndingIndex(4)

ll1.PrintLL()
# ll1.deleteNode(7)
# ll1.PrintLL()
# Out:
# Head Node added Successfully
# Node added at the Begin
# Node added at the Begin
# Node added at the end
# Node added at the end
# Node added at the end
# Node added at the end
# 4 => 3 => 1 => 5 => 6 => 7 => 8 =>
# 4 => 3 => 1 => 6 => 7 => 8 =>
